# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     six-1.16.0                 |     pyhd3eb1b0_0          18 KB
#     pyopenssl-21.0.0           |     pyhd3eb1b0_1          48 KB
#     sqlite-3.37.0              |       hc218d9a_0         1.5 MB
#     wheel-0.37.1               |     pyhd3eb1b0_0          31 KB
#     cffi-1.14.6                |   py36h400218f_0         224 KB
#     openssl-1.1.1m             |       h7f8727e_0         3.8 MB
#     xz-5.2.5                   |       h7b6447c_0         438 KB
#     ld_impl_linux-64-2.35.1    |       h7274673_9         637 KB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     ncurses-6.3                |       h7f8727e_2         1.0 MB
# ...

# %%
import sys
sys.path
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# !conda install -c bioconda megahit
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - megahit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     megahit-1.2.9              |       h2e03b76_1         2.9 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   megahit            bioconda/linux-64::megahit-1.2.9-h2e03b76_1
#
#
# Proceed ([y]/n)? y
#
#
# ...
# megahit-1.2.9        | 2.9 MB    | : 100% 1.0/1 [00:00<00:00,  1.58it/s]
# done
# done
# done

# %%
# !wget https://anaconda.org/bioconda/megahit/1.2.9/download/osx-64/megahit-1.2.9-hfbae3c0_0.tar.bz2
# Out:
# --2022-01-31 22:17:26--  https://anaconda.org/bioconda/megahit/1.2.9/download/osx-64/megahit-1.2.9-hfbae3c0_0.tar.bz2
# Resolving anaconda.org (anaconda.org)... 104.17.92.24, 104.17.93.24, 2606:4700::6811:5d18, ...
# Connecting to anaconda.org (anaconda.org)|104.17.92.24|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# ...

# %%
# !conda install -c bioconda glimmer
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - glimmer
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     glimmer-3.02               |       h1b792b2_5         2.4 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         2.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   glimmer            bioconda/linux-64::glimmer-3.02-h1b792b2_5
#
#
# Proceed ([y]/n)? y
#
#
# ...
# glimmer-3.02         | 2.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.67it/s]
# done
# done
# done

# %%
# !wget https://anaconda.org/bioconda/glimmer/3.02/download/linux-64/glimmer-3.02-he1b5a44_4.tar.bz2
# Out:
# --2022-01-31 22:17:38--  https://anaconda.org/bioconda/glimmer/3.02/download/linux-64/glimmer-3.02-he1b5a44_4.tar.bz2
# Resolving anaconda.org (anaconda.org)... 104.17.92.24, 104.17.93.24, 2606:4700::6811:5d18, ...
# Connecting to anaconda.org (anaconda.org)|104.17.92.24|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# ...

# %%
# !conda install -c bioconda sra-tools
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 4.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - sra-tools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     sra-tools-2.8.0            |                0        99.7 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:        99.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   sra-tools          bioconda/linux-64::sra-tools-2.8.0-0
#
#
# Proceed ([y]/n)? y
#
#
# ...
# sra-tools-2.8.0      | 99.7 MB   | : 100% 1.0/1 [00:15<00:00, 15.74s/it]
# done
# done
# done

# %%
# !wget https://trace.ncbi.nlm.nih.gov/Traces/sra/?run=SRR12616406
# Out:
# --2022-01-31 22:18:07--  https://trace.ncbi.nlm.nih.gov/Traces/sra/?run=SRR12616406
# Resolving trace.ncbi.nlm.nih.gov (trace.ncbi.nlm.nih.gov)... 130.14.29.113, 2607:f220:41e:4290::113
# Connecting to trace.ncbi.nlm.nih.gov (trace.ncbi.nlm.nih.gov)|130.14.29.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?run=SRR12616406’
#
# index.html?run=SRR1     [ <=>                ]  82.03K   416KB/s    in 0.2s
#
# 2022-01-31 22:18:09 (416 KB/s) - ‘index.html?run=SRR12616406’ saved [84002]

# %%
# !wget https://sra-pub-run-odp.s3.amazonaws.com/sra/SRR12616406/SRR12616406
# Out:
# --2022-01-31 22:18:09--  https://sra-pub-run-odp.s3.amazonaws.com/sra/SRR12616406/SRR12616406
# Resolving sra-pub-run-odp.s3.amazonaws.com (sra-pub-run-odp.s3.amazonaws.com)... 54.231.195.161
# Connecting to sra-pub-run-odp.s3.amazonaws.com (sra-pub-run-odp.s3.amazonaws.com)|54.231.195.161|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1725941543 (1.6G) [binary/octet-stream]
# Saving to: ‘SRR12616406’
#
# SRR12616406         100%[===================>]   1.61G  31.0MB/s    in 48s
#
# 2022-01-31 22:18:57 (34.6 MB/s) - ‘SRR12616406’ saved [1725941543/1725941543]

# %%
# !fastq-dump -F --split-files SRR12616406
# Out:
# Read 16117526 spots for SRR12616406
# Written 16117526 spots for SRR12616406

# %%
# !megahit -1 SRR12616406_1.fastq -2 SRR12616406_2.fastq
# Out:
# 2022-01-31 22:28:30 - MEGAHIT v1.2.9
# 2022-01-31 22:28:30 - Using megahit_core with POPCNT and BMI2 support
# 2022-01-31 22:28:30 - Convert reads to binary library
# 2022-01-31 22:31:56 - b'INFO  sequence/io/sequence_lib.cpp  :   75 - Lib 0 (/content/SRR12616406_1.fastq,/content/SRR12616406_2.fastq): pe, 32235052 reads, 150 max length'
# 2022-01-31 22:31:56 - b'INFO  utils/utils.h                 :  152 - Real: 205.6606\tuser: 30.9755\tsys: 6.3928\tmaxrss: 268960'
# 2022-01-31 22:31:56 - k-max reset to: 141
# 2022-01-31 22:31:56 - Start assembly. Number of CPU threads 2
# 2022-01-31 22:31:56 - k list: 21,29,39,59,79,99,119,141
# 2022-01-31 22:31:56 - Memory used: 12259971072
# 2022-01-31 22:31:56 - Extract solid (k+1)-mers for k = 21
# 2022-01-31 22:49:14 - Build graph for k = 21
# 2022-01-31 22:50:01 - Assemble contigs from SdBG for k = 21
# 2022-01-31 22:51:44 - Local assembly for k = 21
# 2022-01-31 22:54:07 - Extract iterative edges from k = 21 to 29
# ...

# %%
# !build-icm model.icm < megahit_out/final.contigs.fa

# %%
# !glimmer3 megahit_out/final.contigs.fa /content/model.icm output.ref
# Out:
# Streaming output truncated to the last 5000 lines.
# Analyzing Sequence #1279
# Start Find_Orfs
# Start Score_Orfs
# Start Process_Events
# Start Trace_Back
# Analyzing Sequence #1280
# Start Find_Orfs
# Start Score_Orfs
# Start Process_Events
# Start Trace_Back
# Analyzing Sequence #1281
# Start Find_Orfs
# Start Score_Orfs
# Start Process_Events
# Start Trace_Back
# Analyzing Sequence #1282
# Start Find_Orfs
# Start Score_Orfs
# Start Process_Events
# Start Trace_Back
# Analyzing Sequence #1283
# Start Find_Orfs
# Start Score_Orfs
# Start Process_Events
# Start Trace_Back
# Analyzing Sequence #1284
# Start Find_Orfs
# Start Score_Orfs
# Start Process_Events
# Start Trace_Back
# Analyzing Sequence #1285
# Start Find_Orfs
# Start Score_Orfs
# Start Process_Events
# Start Trace_Back
# Analyzing Sequence #1286
# Start Find_Orfs
# Start Score_Orfs
# Start Process_Events
# Start Trace_Back
# Analyzing Sequence #1287
# Start Find_Orfs
# Start Score_Orfs
# Start Process_Events
# ...
