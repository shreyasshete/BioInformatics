# %%
with open('C:/Users/nisch/Downloads/Kushal/Kushal/annotations/Length_bp.txt') as f:
    lines = f.readlines()

# %%
lines
# Out:
# ['length_bp\n',
#  '381\n',
#  '603\n',
#  '201\n',
#  '321\n',
#  '597\n',
#  '276\n',
#  '165\n',
#  '177\n',
#  '234\n',
#  '468\n',
#  '210\n',
#  '369\n',
#  '768\n',
#  '330\n',
#  '525\n',
#  '258\n',
#  '411\n',
#  '429\n',
#  '1011\n',
#  '237\n',
#  '414\n',
#  '435\n',
#  '291\n',
#  '495\n',
#  '2316\n',
#  '339\n',
#  '195\n',
#  '474\n',
#  '192\n',
#  '312\n',
#  '630\n',
#  '606\n',
#  '303\n',
#  '825\n',
#  '279\n',
#  '333\n',
#  '699\n',
#  '411\n',
#  '192\n',
#  '255\n',
#  '372\n',
#  '315\n',
#  '540\n',
#  '306\n',
#  '393\n',
#  '534\n',
#  '354\n',
#  '504\n',
#  '180\n',
#  '435\n',
#  '1332\n',
#  '117\n',
#  '357\n',
#  '390\n',
#  '621\n',
#  '990\n',
#  '390\n',
#  '426\n',
#  '201\n',
#  '405\n',
#  '1377\n',
#  '1290\n',
#  '948\n',
#  '513\n',
#  '1122\n',
#  '474\n',
#  '540\n',
#  '573\n',
#  '822\n',
#  '543\n',
#  '390\n',
#  '951\n',
#  '993\n',
#  '1284\n',
#  '297\n',
#  '486\n',
#  '858\n',
#  '408\n',
#  '93\n',
#  '1326\n',
#  '204\n',
# ...

# %%
# Creating histogram

from matplotlib import pyplot as plt
import numpy as np
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(lines, bins = [0, 25, 50, 75, 100])
 
# Show plot
plt.show()
